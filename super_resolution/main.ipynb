# %%
import numpy as np
import matplotlib.pyplot as plt

from data import get_train_set
from dataset import load_image

from torchvision.models import resnet34
import torch

# %%
net = resnet34(pretrained=True)

# %%
x = torch.rand((1, 3, 32, 32), dtype=torch.float32)

# %%
I = np.random.rand(64, 32, 32, 16)
r = 4

# %%
I.shape
# Out:
# (64, 32, 32, 16)

# %%
a
# Out:
# 32

# %%
np.split()

# %%
bsize, a, b, c = I.shape
print(bsize, a, b, c)

bsize = np.shape(I)[0] # Handling Dimension(None) type for undefined batch dim
print(bsize)

X = np.reshape(I, (bsize, a, b, r, r))
print(X.shape)

X = np.split(X, a, 1)  # a, [bsize, b, r, r]
print(len(X))
X = np.concatenate([np.squeeze(x, axis=1) for x in X], 2)  # bsize, b, a*r, r

X = np.split(X, b ,1)  # b, [bsize, a*r, r]
X = np.concatenate([np.squeeze(x, axis=1) for x in X], 2)  # bsize, a*r, b*r

X = np.reshape(X, (bsize, a*r, b*r, 1))
# Out:
# 64 32 32 16
# 64
# (64, 32, 32, 4, 4)
# 32

# %%
X.shape
# Out:
# (64, 128, 128, 1)

# %%
net.layer4
# Out:
# Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
# ...

# %%
train_set = get_train_set()

# %%
input, target = train_set[10]

# %%
def imshow(img):
    plt.imshow(np.transpose(img, (1, 2, 0)))
    plt.show()

# %%
imshow(input)

# %%
imshow(target)
